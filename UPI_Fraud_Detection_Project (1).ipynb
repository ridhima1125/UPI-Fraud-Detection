# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn imbalanced-learn streamlit faker
# Out:
# Requirement already satisfied: pandas in c:\users\lenovo\appdata\roaming\python\python313\site-packages (3.0.3)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\roaming\python\python313\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\lenovo\appdata\roaming\python\python313\site-packages (3.10.9)
# Requirement already satisfied: seaborn in c:\users\lenovo\appdata\roaming\python\python313\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\appdata\roaming\python\python313\site-packages (1.8.0)
# Requirement already satisfied: imbalanced-learn in c:\users\lenovo\appdata\roaming\python\python313\site-packages (0.14.1)
# Requirement already satisfied: streamlit in c:\users\lenovo\appdata\roaming\python\python313\site-packages (1.58.0)
# Requirement already satisfied: faker in c:\users\lenovo\anaconda3\lib\site-packages (40.19.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (7.1.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (7.35.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (1.2.0)
# Requirement already satisfied: uvicorn>=0.30.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (0.48.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (0.0.29)
# Requirement already satisfied: websockets>=12.0.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.21.2)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (3.17)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (2026.5.20)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2026.5.1)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\users\lenovo\appdata\roaming\python\python313\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
fake = Faker('en_IN')      
np.random.seed(42)         
random.seed(42)
n = 50000                   
fraud_ratio = 0.02      
merchants = ['Swiggy','Zomato','Amazon','Flipkart','BigBasket',
             'PhonePe','Paytm','Google Pay','IRCTC','BookMyShow',
             'Unknown_Merchant','Temp_Account','New_User_9999']
states = ['UP','Delhi','Maharashtra','Karnataka','Tamil Nadu',
          'Gujarat','Rajasthan','Bihar','West Bengal','Punjab']
data = []
for i in range(n):
    is_fraud = 1 if random.random() < fraud_ratio else 0
    hour = random.choice([2,3,4]) if is_fraud else random.randint(8,22)
    amount = round(random.uniform(50000,200000),2) if is_fraud else round(random.uniform(10,5000),2)
    merchant = random.choice(merchants[10:]) if is_fraud else random.choice(merchants[:10])
    new_device = 1 if is_fraud and random.random()<0.8 else 0
    failed_before = random.randint(3,10) if is_fraud else random.randint(0,1)
    diff_state = 1 if is_fraud and random.random()<0.7 else 0
    data.append({
        'transaction_id': f'TXN{100000+i}',
        'sender_upi': fake.bothify('????####@upi'),
        'receiver_upi': fake.bothify('????####@upi'),
        'amount': amount,
        'merchant': merchant,
        'hour_of_day': hour,
        'state': random.choice(states),
        'new_device': new_device,
        'failed_attempts_before': failed_before,
        'different_state': diff_state,
        'is_fraud': is_fraud    
    })
df = pd.DataFrame(data)
df.to_csv('upi_transactions.csv', index=False)
print(f"Dataset ready! Total: {n}, Fraud: {df['is_fraud'].sum()}")
# Out:
# C:\Users\lenovo\AppData\Roaming\Python\Python313\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Dataset ready! Total: 50000, Fraud: 1000

# %%
print(df.head())             
print("\nShape:", df.shape)  
print("\nFraud count:\n", df['is_fraud'].value_counts())
# Out:
#   transaction_id    sender_upi  receiver_upi   amount  merchant  hour_of_day  \
# 0      TXN100000  QEsV06959upi   nXZf8101upi  3710.34  Flipkart            8
# 1      TXN100001  pkRh45604upi   CAPe7659upi  3705.93     IRCTC           18
# 2      TXN100002   VlTw3776upi   BgPr2932upi   477.54  Flipkart            8
# 3      TXN100003   rHOr4843upi   UmRl7022upi  3509.61     Paytm           18
# 4      TXN100004  kjFd34291upi  KHax61399upi  4347.81    Amazon           20
#
#          state  new_device  failed_attempts_before  different_state  is_fraud
# 0  Maharashtra           0                       0                0         0
# 1       Punjab           0                       0                0         0
# 2  West Bengal           0                       0                0         0
# 3        Bihar           0                       0                0         0
# 4      Gujarat           0                       1                0         0
#
# Shape: (50000, 11)
#
# Fraud count:
#  is_fraud
# 0    49000
# 1     1000
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, axes = plt.subplots(1, 2, figsize=(12,4))
df[df['is_fraud']==0]['amount'].clip(upper=10000).plot(
    kind='hist', bins=50, ax=axes[0],
    color='#1D9E75', title='Normal Transactions Amount')
df[df['is_fraud']==1]['amount'].plot(
    kind='hist', bins=50, ax=axes[1],
    color='#D85A30', title='Fraud Transactions Amount')
plt.tight_layout()
plt.show()

# %%
fraud_by_hour = df.groupby(['hour_of_day','is_fraud']).size().unstack()
fraud_by_hour.plot(kind='bar', figsize=(14,5), color=['#1D9E75','#D85A30'])
plt.title('Transactions by Hour — Fraud vs Normal')
plt.xlabel('Hour of Day (0 = midnight, 12 = noon)')
plt.legend(['Normal','Fraud'])
plt.show()

# %%
numeric_cols = ['amount','hour_of_day','new_device',
                'failed_attempts_before','different_state','is_fraud']
plt.figure(figsize=(8,6))
sns.heatmap(df[numeric_cols].corr(),
            annot=True,     
            fmt='.2f',      
            cmap='Greens',
            linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
features = ['amount','hour_of_day','new_device',
            'failed_attempts_before','different_state']
X = df[features]           
y = df['is_fraud']     
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42)
print("Training data:", X_train.shape)
print("Testing data:", X_test.shape)
# Out:
# Training data: (40000, 5)
# Testing data: (10000, 5)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X_train, y_train)
print("SMOTE se pehle:")
print("  Normal:", (y_train==0).sum(), "| Fraud:", y_train.sum())
print("\nSMOTE ke baad:")
print("  Normal:", (y_res==0).sum(), "| Fraud:", y_res.sum())
# Out:
# SMOTE se pehle:
#   Normal: 39206 | Fraud: 794
#
# SMOTE ke baad:
#   Normal: 39206 | Fraud: 39206

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_res, y_res)
y_pred = model.predict(X_test)
print("=== Model Results ===")
print(classification_report(y_test, y_pred,
      target_names=['Normal','Fraud']))
# Out:
# === Model Results ===
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00      9794
#        Fraud       1.00      1.00      1.00       206
#
#     accuracy                           1.00     10000
#    macro avg       1.00      1.00      1.00     10000
# weighted avg       1.00      1.00      1.00     10000

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,5))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=['Normal','Fraud'],
            yticklabels=['Normal','Fraud'], ax=axes[0])
axes[0].set_title('Confusion Matrix')
feat_imp = pd.Series(model.feature_importances_,
                     index=features).sort_values()
feat_imp.plot(kind='barh', color='#1D9E75', ax=axes[1])
axes[1].set_title('Feature Importance')
plt.tight_layout()
plt.show()
